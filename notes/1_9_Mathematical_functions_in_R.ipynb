# %% [markdown]
# # Mathematical functions in R
#
# R is a statistical programming language and so has a standard complement of common mathematical functions.
#
# Help for mathematical functions can be accessed with: `?groupGeneric, ?Special, ?Bessel`.

# %%
math_functions <- data.frame(Function = c("abs", "sign", "sqrt", "floor",
                        "ceiling", "trunc", "round", "signif", "exp",
                        "log", "expm1", "log1p", "cos", "sin", "tan",
                        "acos", "asin", "atan", "cosh", "sinh", "tanh",
                        "acosh", "asinh", "atanh", "lgamma", "gamma",
                        "psigamma", "digamma", "trigamma", "cumsum", 
                        "cumprod", "cummax", "cummin", "beta", "lbeta",
                        "choose", "lchoose", "factorial", "lfactorial",
                        "min", "max", "range"),
                        Description = c("Absolute value",
                        "Sigum funciton", "Square root", 
                        "Rounds down to nearset integer",
                        "Rounds up to nearest integer",
                        "Truncates number down to nearest integer",
                        "Rounds to specified decimal digits",
                        "Rounds to specified significant digits",
                        "Exponential function to base e",
                        "log to specified base defaults to e",
                        "exp(x) - 1", "Computes log(1 + x)",
                        "Cosine function", "Sine function",
                        "Tangent function", "Arc cosine", "Arc sine",
                        "Arc tangent", "Hyperbolic cosine",
                        "Hyperbolic sine", "Hyperbolic tangent",
                        "Arc hyperbolic cosine", "Arc hyperbolic sine",
                        "Arc hyperbolic tangent",
                        "Log of the gamma function", "Gamma function",
                        "Specified derivative of the log Gamma function",
                        "Second derivative of the log Gamma function",
                        "Third derivative of the log Gamma function",
                        "Cumulative sum", "Cumulative product",
                        "Cumulative maximum", "Cumulative minimum",
                        "Beta function", "Log of Beta function",
                        "N, k choose function", "Log of the choose function",
                        "Factorial", "Log of factorial", "Minimum of vector",
                        "Maximum of vector", "Minimun and maximum of vector"))

math_functions
# Out:
#    Function   Description
# 1  abs        Absolute value
# 2  sign       Sigum funciton
# 3  sqrt       Square root
# 4  floor      Rounds down to nearset integer
# 5  ceiling    Rounds up to nearest integer
# 6  trunc      Truncates number down to nearest integer
# 7  round      Rounds to specified decimal digits
# 8  signif     Rounds to specified significant digits
# 9  exp        Exponential function to base e
# 10 log        log to specified base defaults to e
# 11 expm1      exp(x) - 1
# 12 log1p      Computes log(1 + x)
# 13 cos        Cosine function
# 14 sin        Sine function
# 15 tan        Tangent function
# 16 acos       Arc cosine
# 17 asin       Arc sine
# 18 atan       Arc tangent
# 19 cosh       Hyperbolic cosine
# 20 sinh       Hyperbolic sine
# 21 tanh       Hyperbolic tangent
# 22 acosh      Arc hyperbolic cosine
# 23 asinh      Arc hyperbolic sine
# 24 atanh      Arc hyperbolic tangent
# 25 lgamma     Log of the gamma function
# 26 gamma      Gamma function
# ...

# %% [markdown]
# Bessel functions are also available, see ?Bessel for more details
